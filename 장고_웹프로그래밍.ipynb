# %% [markdown]
# <a href="https://colab.research.google.com/github/gfinemax/AI_ROBOT_2211/blob/main/%EC%9E%A5%EA%B3%A0_%EC%9B%B9%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###1. 프런트엔드로만 구성한 웹사이트
# ![image.png](data:image/png;base64,...)

# %%
### 1-2 <a href="about_me.html">about me</a>

# %% [markdown]
# ## 11-2 <a href="about_me.html">about me</a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
